# %% [markdown]
# <div style="text-align: center;">
# <h2>INFSCI 2915 Foundations- Machine Learning - Spring 2018 </h2>
# <h1 style="font-size: 250%;">Assignment #3</h1>
# <h3>Issued Monday, 3/26/2018; Due Monday, 11:59pm, 4/09/2018</h3>
# <h3>Total points: 100 </h3>
# </div>

# %%
# Type in your information in the double quotes
firstName = "Vaishnavi"
lastName = "Deshpande"
pittID = "vad28@pitt.edu"

# %% [markdown]
# <h3>  Problem #1.Linear Discriminant Analysis (LDA)and Quadratic Discriminant Analysis(QDA)      <br>[30 points]</h3>
#  Writing a code is not required for this problem.

# %% [markdown]
# <h4> Problem #1-1</h4>  <br>
# Assume we have K classes to be classified with one feature $(x)$. The prior probability of
# class $k$ is $𝜋_{k} = 𝑃(𝑌 = 𝑘)$. Assume that the feature in class k has Gaussian distribution of
# mean $μ_{k}$ and variance $σ^2 (𝒩(μ,𝜎^{2}))$.The variance is the same for all classes.
# Prove that the Bayes’ classifier (that chooses class k with largest $𝑃(𝑌 = 𝑘|𝑥))$ is equivalent to assigning an observation to the class for which the discriminant function $𝛿_{k}(x)$ is
# maximized, where
# \begin{array} \\
# 𝛿_{k}(x) = x\frac{\mu _{k}}{\sigma ^{2}}- \frac{\mu_{2}^{k}}{2\sigma ^{2}}+ log(\pi _{k})
# \end{array}
# <br> What is the name of this classifier?

# %% [markdown]
# #Write your narrative answer here (no code is needed for this part)
# ![image.png](attachment:image.png)

# %% [markdown]
# <h4> Problem #1-2</h4>  <br>
# Extend **Problem #1-1** to include **p** features. With features from each class drawn from a
# Gaussian distribution with mean vector $μ_{k}$ and covariance matrix $Σ_{k}$ (which is now
# different for each class). Find the discriminant function that maximizes **𝑃(𝑌 = 𝑘|𝑥)**. Is
# the relationship with the feature vector **x** linear?<br> What is this classifier?

# %% [markdown]
# #Write your narrative answer here (no code is needed for this part)
# ![image.png](attachment:image.png)

# %% [markdown]
# <h4> Problem #1-3</h4>  <br>
# - Explain Bias-variance trade-off in choosing between LDA and QDA

# %% [markdown]
# #Write your narrative answer here (no code is needed for this part)
#
# Bias Variannce trade off  between the LDA and QDA are as follows
# LDA is simpler but can lead to high bias.It estimates single covariance matrix
#
# The difference is really a bias-variance trade-off. With p predictors, estimating a co variance matrix requires estimating p(p+1)/2 parameters. The QDA estimates a separate co variance matrix for each class, so as the number of predictors becomes high, we experience a computational expense. Conversely, if we assume a common co variance matrix, we only have to do the computation once. LDA is a much less flexible classifier, than QDA, thus has substantially lower variance. However, if the assumption of uniform variance is highly off, then LDA can suffer high bias. In general, LDA tends to be better than QDA if there are relatively few training observations, so therefore reducing variance is crucial. QDA is recommended if the training set is very large, so that the variance of the classifier is not a major concern.
#
# Between Logistic regression LDA and QDA, the biggest things to take into consideration are the type of decision boundary that is required. If highly linear, than LDA and Logistic may prove superior, if non-linear, the edge may be given to QDA. Though keep in mind we can do simple transformations to take non-linearity into consideration with Logistic models, similar to how we did in linear regression.
# Bias Variannce trade off  between the LDA and QDA are as follows
# LDA is simpler but can lead to high bias.It estimates single covariance matrix
#
# Reference:https://rpubs.com/ryankelly/LDA-QDA

# %% [markdown]
# <h3>  Problem #2. Support Vector Machines  [20 points]</h3>
# Writing a code is not required for this problem.

# %% [markdown]
# <h4> Problem #2-1 Answer the following quesionts </h4>
#
# - Describe limitations of using Maximal Margin Classifier
# - What is the difference between Support Vector Classifier and Maximal Margin Classifier
# - Explain Bias-variance trade-off that occurs when we choose large and small values for the Slack Variables

# %% [markdown]
# 2-1a)
# Limitations of Maximal Margin classifier includes the following
#
# -It is very sensitive to training data
#
# -Classes may not be perfectly separable by a hyperplane .If classes are not separable then there won’t be any solution for the previously formulated optimization problem
#
# -Assumes that the classes can be perfectly separable, which is not always the case.

# %% [markdown]
# 2-1b)
# The support vector classifier is the generalization of maximal margin classifier to the non-separable case
#
# Maximum Margin Classifier
#
# -Finds the hyperplane (linear decision boundary) that maximizes the margin (gap) between two classes in the feature space.
#
# -The maximum margin classifier depends on the support vectors and not on other training observations.
#
# -The hope is that largest margin on training data will also work well on test data.
#
# SVM:
#
# -In many cases classes will not be perfectly separable.
#
# -Support vector classifier allows some training observations to be in the incorrect side of the hypeargin rplane (decision boundary).
#
# -It defines a soft margin, which allows observation points to be within this margin.

# %% [markdown]
# 2-1C)
# ![image.png](attachment:image.png)
#
# It limits the the number and severity of violation to margin and boundary.
#
# The constant C is a tuning parameter that we choose (similar to regularization)
#
# • Large C, more tolerance to violation -> wide margin->large bias, small variance
#
#
# • Small C, less tolerance to violation -> narrow margin ->small bias, large variance

# %% [markdown]
# <h3>  Problem #3 Classification Performance Evaluation and Cross validation [30 points]</h3>

# %% [markdown]
# <h4> Problem #3-1</h4> <br>
# In a fraud detection system, a QDA classifier’s confusion matrix is found to be:

# %% [markdown]
# |        |Predicted Class - Not fraud| Predicted Class - fraud|
# |:--:|:-------------------------------:|
# |Actual class – Not fraud|1000|20|
# |Actual class – fraud|30|5|

# %% [markdown]
# - Evaluate the overall error rate and the accuracy<br>
# - Evaluate the precision and the recall <br>
# - Is dataset balanced?
# - Comment on the results.

# %% [markdown]
# #Write your narrative answer here (no code is needed for this)
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The dataset consists of Skewed classes and hence the dataset is not balanced.There is no sufficient training examples for one of the classes. Therefore accuracy and error rate are not one of the the best measures for this kind of  dataset. Other measure reflect the performance better.

# %% [markdown]
# <h4> Problem #3-2</h4> <br>
# Assuming we want to lower the misclassification of fraud. How can you modify the classifier to do better classification using information from confusion matrix?

# %% [markdown]
# #Write your narrative answer here (no code is needed for this part)
#
# The performance can be better understood  through the confusion matrix.Modifying the classifier helps us to do better job based on the requirement. We can modify the classifier by changing the 0.5 threshold to obtain better performance.

# %% [markdown]
# <h4> Problem #3-3 Cross validation, SVM </h4> <br>
# In this exercise, we will use SVM  for breast cancer classification (malignant or benign).<br>
# Use a code below to download the dataset:

# %%
from sklearn.datasets import load_breast_cancer
dataset = load_breast_cancer()
print(dataset.keys())
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %% [markdown]
# Follow steps to answer questions.
# - Scale the features with MinMaxScaler
# - Split breast cancer dataset into two, test dataset and train dataset
# - Find best SVM classifier model. Try values of C=[0.001, 0.1, 1, 10, 1000] and Gamma = [0.001, 0.1, 1, 10, 1000].
# - Use 3-fold cross validation to find the best parameters (using all possible combinations of these values for C and gamma).
# - Report your parameters
# - Report accuracy, confusion matrix, precision, and recall (use Test dataset, SVM classifier model with best parameters)
# - Comment your results

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn.utils import shuffle
dataset = load_breast_cancer()
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
scaler = MinMaxScaler()
X = scaler.fit_transform(df)
X_train_scaled, X_test_scaled, Y_train, Y_test = train_test_split(X,dataset.target,random_state=0)
kfolds = 3
best_score = 0
for c_parameter in [0.001, 0.1, 1, 10, 1000]: #iterate over the values we need to try for the parameter C
    for gamma_parameter in [0.001, 0.1, 1, 10, 1000]: #iterate over the values we need to try for the parameter gamma
        svmModel = SVC(kernel='rbf', C=c_parameter, gamma=gamma_parameter) #define the model
        # perform cross-validation
        scores = cross_val_score(svmModel, X_train_scaled, Y_train, cv=kfolds)
        # the training set will be split internally into training and cross validation
        # compute mean cross-validation accuracy
        score = np.mean(scores)
        print("score with parameter C =", c_parameter, " & gamma =", gamma_parameter, " is ", score)
        # if we got a better score, store the score and parameters
        if score > best_score:
            best_score = score #store the score 
            best_parameter_c = c_parameter #store the parameter c
            best_parameter_gamma = gamma_parameter #store the parameter gamma
print('The best score is\n',best_score,'for the best parameter C =',best_parameter_c,'and for best parameter gamma =',best_parameter_gamma)
from sklearn.metrics import confusion_matrix, precision_score, recall_score
best_svm = SVC(kernel='rbf', C=best_parameter_c, gamma=best_parameter_gamma)
best_svm.fit(X_train_scaled, Y_train)
print ('The accuracy will be\n' ,best_svm.score(X_test_scaled,Y_test))
PredictedOutput=best_svm.predict(X_test_scaled) # predicted output of classification
confusion=confusion_matrix(Y_test,PredictedOutput)
print('The confusion matrix is\n',confusion)
print('The precision score is\n',precision_score(Y_test,PredictedOutput))
print('The recall score is\n',recall_score(Y_test,PredictedOutput))
# Out:
# score with parameter C = 0.001  & gamma = 0.001  is  0.62676056338
# score with parameter C = 0.001  & gamma = 0.1  is  0.62676056338
# score with parameter C = 0.001  & gamma = 1  is  0.62676056338
# score with parameter C = 0.001  & gamma = 10  is  0.62676056338
# score with parameter C = 0.001  & gamma = 1000  is  0.62676056338
# score with parameter C = 0.1  & gamma = 0.001  is  0.62676056338
# score with parameter C = 0.1  & gamma = 0.1  is  0.87558685446
# score with parameter C = 0.1  & gamma = 1  is  0.943661971831
# score with parameter C = 0.1  & gamma = 10  is  0.629107981221
# score with parameter C = 0.1  & gamma = 1000  is  0.62676056338
# score with parameter C = 1  & gamma = 0.001  is  0.62676056338
# score with parameter C = 1  & gamma = 0.1  is  0.953051643192
# score with parameter C = 1  & gamma = 1  is  0.978873239437
# score with parameter C = 1  & gamma = 10  is  0.934272300469
# score with parameter C = 1  & gamma = 1000  is  0.62676056338
# score with parameter C = 10  & gamma = 0.001  is  0.880281690141
# score with parameter C = 10  & gamma = 0.1  is  0.978873239437
# score with parameter C = 10  & gamma = 1  is  0.978873239437
# score with parameter C = 10  & gamma = 10  is  0.924882629108
# score with parameter C = 10  & gamma = 1000  is  0.62676056338
# score with parameter C = 1000  & gamma = 0.001  is  0.976525821596
# score with parameter C = 1000  & gamma = 0.1  is  0.962441314554
# score with parameter C = 1000  & gamma = 1  is  0.93896713615
# score with parameter C = 1000  & gamma = 10  is  0.924882629108
# score with parameter C = 1000  & gamma = 1000  is  0.62676056338
# The best score is
#  0.978873239437 for the best parameter C = 1 and for best parameter gamma = 1
# The accuracy will be
#  0.972027972028
# The confusion matrix is
#  [[50  3]
#  [ 1 89]]
# The precision score is
#  0.967391304348
# The recall score is
#  0.988888888889

# %% [markdown]
# <h4> Problem #3-4 Cross validation, Logistic regression </h4>
#
# - Repeat **Problem #3-3** but instead of SVM find best Logistic regression classifier model. Try values of C= [0.001,0.01,1,10,100, 1000] and Penalty = ["l1","l2"]

# %%
#Write your answer here
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn.utils import shuffle
dataset = load_breast_cancer()
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
scaler = MinMaxScaler()
X = scaler.fit_transform(df)
X_train_scaled, X_test_scaled, Y_train, Y_test = train_test_split(X,dataset.target,random_state=0)
kfolds = 3
best_score = 0
for c_parameter in [0.001, 0.1, 1, 10, 1000]: #iterate over the values we need to try for the parameter C
    for gamma_parameter in [0.001, 0.1, 1, 10, 1000]: #iterate over the values we need to try for the parameter gamma
        svmModel = SVC(kernel='rbf', C=c_parameter, gamma=gamma_parameter) #define the model
        # perform cross-validation
        scores = cross_val_score(svmModel, X_train_scaled, Y_train, cv=kfolds)
        # the training set will be split internally into training and cross validation
        # compute mean cross-validation accuracy
        score = np.mean(scores)
        print("score with parameter C =", c_parameter, " & gamma =", gamma_parameter, " is ", score)
        # if we got a better score, store the score and parameters
        if score > best_score:
            best_score = score #store the score 
            best_parameter_c = c_parameter #store the parameter c
            best_parameter_gamma = gamma_parameter #store the parameter gamma
print('The best score is \n',best_score,'for the best parameter C =',best_parameter_c,'and for best parameter gamma =',best_parameter_gamma)
from sklearn.metrics import confusion_matrix, precision_score, recall_score
best_svm = SVC(kernel='rbf', C=best_parameter_c, gamma=best_parameter_gamma)
best_svm.fit(X_train_scaled, Y_train)
print ('The accuracy will be\n' ,best_svm.score(X_test_scaled,Y_test))
PredictedOutput=best_svm.predict(X_test_scaled) # predicted output of classification
confusion=confusion_matrix(Y_test,PredictedOutput)
print('The confusion matrix is\n',confusion)
print('The precision score is\n',precision_score(Y_test,PredictedOutput))
print('The recall score is\n',recall_score(Y_test,PredictedOutput))
# Out:
# score with parameter C = 0.001  & gamma = 0.001  is  0.62676056338
# score with parameter C = 0.001  & gamma = 0.1  is  0.62676056338
# score with parameter C = 0.001  & gamma = 1  is  0.62676056338
# score with parameter C = 0.001  & gamma = 10  is  0.62676056338
# score with parameter C = 0.001  & gamma = 1000  is  0.62676056338
# score with parameter C = 0.1  & gamma = 0.001  is  0.62676056338
# score with parameter C = 0.1  & gamma = 0.1  is  0.87558685446
# score with parameter C = 0.1  & gamma = 1  is  0.943661971831
# score with parameter C = 0.1  & gamma = 10  is  0.629107981221
# score with parameter C = 0.1  & gamma = 1000  is  0.62676056338
# score with parameter C = 1  & gamma = 0.001  is  0.62676056338
# score with parameter C = 1  & gamma = 0.1  is  0.953051643192
# score with parameter C = 1  & gamma = 1  is  0.978873239437
# score with parameter C = 1  & gamma = 10  is  0.934272300469
# score with parameter C = 1  & gamma = 1000  is  0.62676056338
# score with parameter C = 10  & gamma = 0.001  is  0.880281690141
# score with parameter C = 10  & gamma = 0.1  is  0.978873239437
# score with parameter C = 10  & gamma = 1  is  0.978873239437
# score with parameter C = 10  & gamma = 10  is  0.924882629108
# score with parameter C = 10  & gamma = 1000  is  0.62676056338
# score with parameter C = 1000  & gamma = 0.001  is  0.976525821596
# score with parameter C = 1000  & gamma = 0.1  is  0.962441314554
# score with parameter C = 1000  & gamma = 1  is  0.93896713615
# score with parameter C = 1000  & gamma = 10  is  0.924882629108
# score with parameter C = 1000  & gamma = 1000  is  0.62676056338
# The best score is
#  0.978873239437 for the best parameter C = 1 and for best parameter gamma = 1
# The accuracy will be
#  0.972027972028
# The confusion matrix is
#  [[50  3]
#  [ 1 89]]
# The precision score is
#  0.967391304348
# The recall score is
#  0.988888888889

# %% [markdown]
# <h3>  Problem #4  Neural Networks [20 points]</h3>
# In this exercise we will clasify Iris species (Setosa, Versicolor, Virginica) using Neural Networks.<br>
# Use a code below to download the dataset:

# %%
from sklearn.datasets import load_iris
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
dataset=load_iris()
print(dataset.keys())
X_train, X_test, Y_train, Y_test = train_test_split(dataset['data'],dataset['target'],random_state=0)
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %% [markdown]
# Follow steps to answer questions.
# - Scale the feautures with MinMaxScaler, then use sklearn MLPClassifier.
# - Build a model that has two hidden layers, the first layer has 10 neurons and second layer has 5 neurons.
# - Use 'relu' activation function, and set the regularization parameter alpha=0.5.
# - Set the random_state=0 for splitting and building all models.

# %% [markdown]
# <h4> Problem #4-1 </h4>
# - Use gradient descent to solve the optimization  problem (i.e. get the weights), and choose random_state=0 (which corresponds to a particular initializationo of weight values).
# - Report accuracy, confusion matrix, precision, and recall

# %%
#Write your answer here
from sklearn import preprocessing
from sklearn.neural_network import MLPClassifier
import pylab as pl
from sklearn.metrics import confusion_matrix, precision_score, recall_score
scaler=preprocessing.MinMaxScaler().fit(X_train) #define scaler depending on the features in training data
X_train_transformed=scaler.transform(X_train) #apply scaling on training set
X_test_transformed=scaler.transform(X_test) #apply scaling on test set
MLPmodel=MLPClassifier(solver='sgd',random_state=0, activation = 'relu', hidden_layer_sizes=[10,5], alpha=0.5)
MLPmodel.fit(X_train_transformed, Y_train)
PredictedOutput_value = MLPmodel.predict(X_test_transformed) # predicted output of classification
print("Accuracy of classifier ", MLPmodel.score(X_test_transformed, Y_test))
Confusion_matrix = confusion_matrix(Y_test,PredictedOutput_value)
print("Confusion matrix\n", Confusion_matrix)
print("Precision of classifier\n ", precision_score(Y_test,PredictedOutput_value, average=None))
print("Recall of classifier\n ", recall_score(Y_test,PredictedOutput_value, average=None))
# Out:
# Accuracy of classifier  0.578947368421
# Confusion matrix
#  [[13  0  0]
#  [11  0  5]
#  [ 0  0  9]]
# Precision of classifier
#   [ 0.54166667  0.          0.64285714]
# Recall of classifier
#   [ 1.  0.  1.]
# C:\Users\rvais\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# C:\Users\rvais\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# <h4> Problem #4-2 </h4>
# - Repeat **Problem #4-1** but with a model that use random_state=10 to initialize the weights.
# - Report accuracy, confusion matrix, precision, and recall

# %%
#Write your answer here
MLPmodel_2=MLPClassifier(solver='sgd',random_state=10, activation = 'relu', hidden_layer_sizes=[10,5], alpha=0.5)
MLPmodel_2.fit(X_train_transformed, Y_train)
PredictedOutput_value = MLPmodel_2.predict(X_test_transformed) # predicted output of classification
print("Accuracy of classifier ", MLPmodel_2.score(X_test_transformed, Y_test))
Confusion_matrix = confusion_matrix(Y_test,PredictedOutputvalue)
print("Confusion matrix \n", Confusion_matrix)
print("Precision of classifier\n ", precision_score(Y_test,PredictedOutput_value, average=None))
print("Recall of classifier\n ", recall_score(Y_test,PredictedOutput_value, average=None))
# Out:
# Accuracy of classifier  0.421052631579
# Confusion matrix
#  [[ 0 13  0]
#  [ 0 16  0]
#  [ 0  9  0]]
# Precision of classifier
#   [ 0.          0.42105263  0.        ]
# Recall of classifier
#   [ 0.  1.  0.]
# C:\Users\rvais\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# C:\Users\rvais\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# <h4> Problem #4-3 </h4>
# - Repeat **Problem #4-2** but with model that use L-BFGS (a numerical quasi-Newton method) instead of stochastic gradient descent to find the weights.
# - Report accuracy, confusion matrix, precision, and recall
# - Comment on results

# %%
#Write your answer here
MLPmodel_3=MLPClassifier(solver='lbfgs',random_state=0, activation = 'relu', hidden_layer_sizes=[10,5], alpha=0.5)
MLPmodel_3.fit(X_train_transformed, Y_train)
PredictedOutput_value = MLPmodel_3.predict(X_test_transformed) # predicted output of classification
print("Accuracy of classifier ", MLPmodel_3.score(X_test_transformed, Y_test))
Confusion_matrix = confusion_matrix(Y_test,PredictedOutput_value)
print("Confusion matrix\n", Confusion_matrix)
print("Precision of classifier\n", precision_score(Y_test,PredictedOutput_value, average=None))
print("Recall of classifier\n ", recall_score(Y_test,PredictedOutput_value, average=None))
# Out:
# Accuracy of classifier  0.973684210526
# Confusion matrix
#  [[13  0  0]
#  [ 0 15  1]
#  [ 0  0  9]]
# Precision of classifier
#  [ 1.   1.   0.9]
# Recall of classifier
#   [ 1.      0.9375  1.    ]
