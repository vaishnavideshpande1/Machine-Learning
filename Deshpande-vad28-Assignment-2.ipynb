# %% [markdown]
# <div style="text-align: center;">
# <h2>INFSCI 2915 Foundations- Machine Learning - Spring 2018 </h2>
# <h1 style="font-size: 250%;">Assignment #2</h1>
# <h3>Issued Monday, 2/26/2018; Due Monday, 11:59pm, 3/12/2018</h3>
# <h3>Total points: 100 </h3>
# </div>

# %%
# Type in your information in the double quotes
firstName = "Vaishnavi "
lastName = "Deshpande"
pittID = "vad28@pitt.edu"

# %% [markdown]
# <h3>  Problem #1. Train Test Split [20 points]</h3>
# In this part, you should download **"Iris dataset"**. <br>
# Use a code below to download the  dataset:

# %%
from sklearn.datasets import load_iris
dataset=load_iris()
print(dataset.keys())
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %% [markdown]
# <h4> Problem #1-1. </h4> Split iris dataset into training and test datasets. (use train_test_split function and random_state=0)
#
# - Report the shape of each (training and test) datasets. What is the proportion of each set?

# %%
#Write your narrative answer here
from sklearn.datasets import load_iris
from sklearn.cross_validation import train_test_split
iris = load_iris()
 # store the feature matrix (X) and response vector (y)
X = iris.data
y = iris.target
 
# splitting X and y into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
 
# printing the shapes of the new X objects
print(X_train.shape)
print(X_test.shape)
 
# printing the shapes of the new y objects
print(y_train.shape)
print(y_test.shape)
# Out:
# (112, 4)
# (38, 4)
# (112,)
# (38,)

# %% [markdown]
# <h4> Problem #1-2. </h4>  Split iris dataset into training and test datasets. Make the proportion of training dataset 60% (use train_test_split function and random_state=0)
#
#
# - Report the shape of each (training and test) datasets.

# %%
#Write your narrative answer here
from sklearn.datasets import load_iris
from sklearn.cross_validation import train_test_split
iris = load_iris()
 # store the feature matrix (X) and response vector (y)
X = iris.data
y = iris.target
 
# splitting X and y into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.6, random_state=0)
 
# printing the shapes of the new X objects
print(X_train.shape)
print(X_test.shape)
 
# printing the shapes of the new y objects
print(y_train.shape)
print(y_test.shape)
# Out:
# (90, 4)
# (60, 4)
# (90,)
# (60,)

# %% [markdown]
# <h4> Problem #1-3. </h4>  Split iris dataset into training and test datasets. Make the proportion of test dataset 33.3% (use train_test_split function and random_state=0)
#
#
# - Report the shape of each (training and test) dataset.

# %%
#Write your narrative answer here
from sklearn.datasets import load_iris
from sklearn.cross_validation import train_test_split
iris = load_iris()
 # store the feature matrix (X) and response vector (y)
X = iris.data
y = iris.target
 
# splitting X and y into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)
 
# printing the shapes of the new X objects
print(X_train.shape)
print(X_test.shape)
 
# printing the shapes of the new y objects
print(y_train.shape)
print(y_test.shape)
# Out:
# (100, 4)
# (50, 4)
# (100,)
# (50,)

# %% [markdown]
# <h4> Problem #1-4. Random State </h4>
# Split iris dataset into training and test datasets, Use different Random State values (0,  10, 253, 1000, 0 and 10)
#
# - Analyze the shape and values of the train and test datasets  generated from different Random State values (you can use descriptive statistics)
#
# - What happens if you do not specify Random State?
#
# - What is a purpose of using Random State?

# %%
#Write your narrative answer here
from sklearn.datasets import load_iris
from sklearn.cross_validation import train_test_split
iris = load_iris()
 # store the feature matrix (X) and response vector (y)
X = iris.data
y = iris.target
 
# splitting X and y into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
 
# printing the shapes of the new X objects
print(X_train.shape)
print(X_test.shape)
 
# printing the shapes of the new y objects
print(y_train.shape)
print(y_test.shape)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10)
 
# printing the shapes of the new X objects
print(X_train.shape)
print(X_test.shape)
 
# printing the shapes of the new y objects
print(y_train.shape)
print(y_test.shape)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=253)
 
# printing the shapes of the new X objects
print(X_train.shape)
print(X_test.shape)
 
# printing the shapes of the new y objects
print(y_train.shape)
print(y_test.shape)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1000)
 
# printing the shapes of the new X objects
print(X_train.shape)
print(X_test.shape)
 
# printing the shapes of the new y objects
print(y_train.shape)
print(y_test.shape)
# Out:
# (112, 4)
# (38, 4)
# (112,)
# (38,)
# (112, 4)
# (38, 4)
# (112,)
# (38,)
# (112, 4)
# (38, 4)
# (112,)
# (38,)
# (112, 4)
# (38, 4)
# (112,)
# (38,)

# %% [markdown]
# If you do not use random state then it does not guarantee that split will always be the same.Everytime time when we run the code, results produced will be different if we don't use random seed
# The main purpose of using the random state is to guarantee that there is equal split always between the test and training data

# %% [markdown]
# <h4> Problem #1-5. Optional (Extra Points) </h4>
#
#
# Write a python function that takes the dataset X  (matrix) and Y (numpy array) as an input and returns two non-overlapping datasets: the training and testing data, such that every entry to training set should be selected randomly. The proportion of the training and testing data should be 75%(training)/25%(test). Test your function using the synthetic dataset below.

# %%
import numpy
# x is your dataset
iris= numpy.random.rand(100, 5)
training_idx = numpy.random.randint(iris.shape[0], size=75)
test_idx = numpy.random.randint(iris.shape[0], size=25)
training, test = iris[training_idx,:], iris[test_idx,:]
print(training)
print(test)
# Out:
# [[ 0.42334206  0.47030615  0.30731387  0.70413302  0.80946333]
#  [ 0.28271091  0.30375319  0.249772    0.02496964  0.75269002]
#  [ 0.01775712  0.05410091  0.54771309  0.74176737  0.02826679]
#  [ 0.05161369  0.59424837  0.17933193  0.38973337  0.22982574]
#  [ 0.21057429  0.2744072   0.66865423  0.8961115   0.6684353 ]
#  [ 0.42402597  0.51681724  0.44580642  0.59382665  0.66107545]
#  [ 0.39709806  0.93902647  0.59379502  0.66509735  0.84065121]
#  [ 0.45795103  0.8335436   0.30280891  0.76212937  0.03908917]
#  [ 0.9419469   0.73675859  0.58938551  0.18342298  0.2930906 ]
#  [ 0.72313961  0.56079327  0.1943011   0.87194641  0.26737731]
#  [ 0.0506466   0.14437231  0.41898296  0.84303347  0.33214747]
#  [ 0.15477267  0.74061134  0.58933477  0.5128922   0.953582  ]
#  [ 0.31589565  0.80157923  0.42350961  0.81517246  0.6418929 ]
#  [ 0.66715529  0.55066998  0.10055493  0.69124135  0.5896241 ]
#  [ 0.46853691  0.96006896  0.88818965  0.03601904  0.52102131]
# ...

# %%
import numpy as np 
import pandas as pd
X = np.stack((np.arange(100), 10*np.array(np.arange(100)),100*np.array(np.arange(100)),1000*np.array(np.arange(100))), axis=-1)
Y = np.random.randint(2, size=100)
df = pd.DataFrame(np.concatenate((X,Y[:,None]),axis=1), columns = ("X1","X2","X3","X4", "Y"))
df.head(10)
# Out:
#    X1  X2   X3    X4  Y
# 0   0   0    0     0  0
# 1   1  10  100  1000  0
# 2   2  20  200  2000  0
# 3   3  30  300  3000  0
# 4   4  40  400  4000  0
# 5   5  50  500  5000  1
# 6   6  60  600  6000  1
# 7   7  70  700  7000  1
# 8   8  80  800  8000  1
# 9   9  90  900  9000  0

# %% [markdown]
# <h3> Problem #2. Feature Selection  [10 points] </h3>  <br>
# In this part, you should download **"Iris dataset"**. <br>
# (use code from problem 1 to download dataset)
#
# - Find the best two features using forward and backward selection to the Iris dataset, use a logistic regression model to find a best subset of features.
# - Comment your choice

# %%
#Write your narrative answer here
from sklearn.datasets import load_boston
dataset = load_boston()
print(dataset.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR'])

# %%
X_train, X_test, Y_train, Y_test= train_test_split(df[['RM']], df['target'], random_state= 0)
linreg= LinearRegression().fit(X_train, Y_train)
score= linreg.score(X_test,Y_test)

print(score)
# Out:
# 0.557649589488

# %%
X_train, X_test, Y_train, Y_test= train_test_split(df[['LSTAT']], df['target'], random_state= 0)
linreg= LinearRegression().fit(X_train, Y_train)
score= linreg.score(X_test,Y_test)

print(score)
# Out:
# 0.457639361556

# %%
X_train, X_test, Y_train, Y_test= train_test_split(df[['TAX']], df['target'], random_state= 0)
linreg= LinearRegression().fit(X_train, Y_train)
score= linreg.score(X_test,Y_test)

print(score)
# Out:
# 0.0952371450838

# %%
X_train, X_test, Y_train, Y_test= train_test_split(df[['CHAS']], df['target'], random_state= 0)
linreg= LinearRegression().fit(X_train, Y_train)
score= linreg.score(X_test,Y_test)

print(score)
# Out:
# 0.0489763879303

# %%
X_train, X_test, Y_train, Y_test= train_test_split(df[['RM','LSTAT']], df['target'], random_state= 0)
linreg= LinearRegression().fit(X_train, Y_train)
score= linreg.score(X_test,Y_test)

print(score)

X_train, X_test, Y_train, Y_test= train_test_split(df[['RM','CHAS']], df['target'], random_state= 0)
linreg= LinearRegression().fit(X_train, Y_train)
score= linreg.score(X_test,Y_test)

print(score)

X_train, X_test, Y_train, Y_test= train_test_split(df[['RM','TAX']], df['target'], random_state= 0)
linreg= LinearRegression().fit(X_train, Y_train)
score= linreg.score(X_test,Y_test)

print(score)

X_train, X_test, Y_train, Y_test= train_test_split(df[['LSTAT','CHAS']], df['target'], random_state= 0)
linreg= LinearRegression().fit(X_train, Y_train)
score= linreg.score(X_test,Y_test)

print(score)

X_train, X_test, Y_train, Y_test= train_test_split(df[['LSTAT','TAX']], df['target'], random_state= 0)
linreg= LinearRegression().fit(X_train, Y_train)
score= linreg.score(X_test,Y_test)

print(score)

X_train, X_test, Y_train, Y_test= train_test_split(df[['CHAS','TAX']], df['target'], random_state= 0)
linreg= LinearRegression().fit(X_train, Y_train)
score= linreg.score(X_test,Y_test)

print(score)
# Out:
# 0.569244541584
# 0.489183148248
# 0.435203893137
# 0.487295247733
# 0.435892100724
# 0.13541548385

# %% [markdown]
# From the output above it is clear that the two best features are RM and LSTAT whose combined score is 0.569244541584 in order to predict the target variable.

# %% [markdown]
# # Recursive Feature Elimination

# %% [markdown]
# <h3>  Problem #3. Qualitative Variables  [10 points] </h3>
#
# In this part, you should download and analyze **"Boston House Prices"** dataset. <br>
# Use a code below to download the  dataset:

# %%
from sklearn.datasets import load_boston
dataset = load_boston()
print(dataset.keys())
print(dataset.feature_names)
print(dataset.DESCR)
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR'])
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# Boston House Prices dataset
# ...
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
# ...

# %% [markdown]
# <h4> Problem #3-1. </h4> Follow steps to answer questions.
# > *Use train_test_split() with the option "random_state=0".
#
# - Identify qualitative feature in the dataset (a feature with dummy variable). What is an abbreviation for the qualitative feature? (What is a definition of that  abbreviation ?)
#
# - Fit a linear regression model with qualitative variable feature only. Report intercept and coefficient.
#
# - What can you infer about the qualitative feature from the coefficient? (Hint check lecture:  "Regression with Qualitative Features")

# %% [markdown]
# Qualitative feature in the dataset i.e the one with dummy variable is Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# 'CHAS' is the abbreviation for qualitative variable .

# %%
#Write your narrative answer here
# %matplotlib notebook
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import preprocessing
from pandas import read_csv
from sklearn.datasets import load_boston
dataset = load_boston()
x_train, x_test, y_train, y_test = train_test_split(dataset.data[:,[3]], dataset.target, random_state=0)


linreg=LinearRegression()
print(dataset.feature_names)
fitted_linreg=linreg.fit(x_train,y_train)
y_pred=fitted_linreg.predict(x_test)

#from sklearn.metrics import r2_score
#r2score=r2_score(y_test, y_pred)
#print("r2=",r2score)


print('coefficients of feature is', linreg.coef_)
print("The intercept is: ", linreg.intercept_)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# coefficients of feature is [ 5.78059887]
# The intercept is:  22.2274011299

# %% [markdown]
# Qualitative feature of the coefficient suggests that there is strong relation between  'CHAS' and the target 'MEDV"

# %% [markdown]
# <h3>  Problem #4. Regularization [30 points]  </h3>

# %% [markdown]
# <h4> Problem #4-1. </h4> Answer the following questions
#
# - What is the objective using regularization?
# - Do you need to use regularization if you have only 1 feature (B0 and B1)?

# %% [markdown]
# 4-1-a)Regularization is a process of introducing additional information in order to solve an ill-posed problem or to prevent overfitting.
# Regularization adds a penalty on the different parameters of the model to reduce the freedom of the model. Hence, the model will be less likely to fit the noise of the training data and will improve the generalization abilities of the model.
#
#
# 4-1-b)We do need to use regularization even if we have a single feature.When there is 1 feature, number of observations will be greater than feature (n >> p) so we won't have the overfitting problem thereby eliminating the need for regularization.

# %% [markdown]
# <h4> Problem #4-2.Ridge Regression </h4>  <br>
# In this part, you should download and analyze **"Boston House Prices"** dataset. <br>
# Use a code below to download the  dataset:

# %%
dataset = load_boston()
print(dataset.keys())

# %% [markdown]
# Follow steps to answer questions.
# - Fit a linear regression model with all features and report the estimated coefficients for the fitted model (do not just print summary, make a table with feature names and estimated coefficients)
# -  Fit a ridge regression model with λ = 1. Report the estimated coefficients for the fitted model.
# -  Fit a ridge regression model with λ = 0. Report the estimated coefficients for the fitted model.
# - Compare estimated coefficients of ridge regression models with λ = 1 and λ = 0  and linear regression model. (you can use descriptive statistics)
# - What did you observe from this comparison?
# - Comment your observation.

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
boston = load_boston()
print(boston.keys())
print(boston.data.shape)
print(boston.feature_names)
print(boston.DESCR)
bos = pd.DataFrame(boston.data)
bos.head()
bos.colums=boston.feature_names
bos.head()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR'])
# (506, 13)
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# Boston House Prices dataset
# ...
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
# ...

# %%
#Write your narrative answer here
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
dataset = load_boston()
import pandas as pd
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
df = (pd.DataFrame(dataset.data, columns= dataset.feature_names))
df['target'] = dataset.target
Y = df['target']
X = df
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=0)
lm = linear_model.LinearRegression()
model = lm.fit(X_train,Y_train)
print ('the coefficient value is', lm.coef_)
print ('the intercept value is', lm.intercept_)
pd.DataFrame(list(zip(X.columns, lm.coef_)), columns = ['features','estimatedCoefficients'])
# Out:
# C:\Users\rvais\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# the coefficient value is [ -4.51283485e-16   0.00000000e+00   4.44089210e-16  -3.30291350e-15
#   -1.70696790e-14  -8.46545056e-16  -1.11022302e-16   1.73472348e-16
#   -7.21644966e-16   1.66533454e-16   4.75314232e-16   3.92047506e-16
#    8.32667268e-17   1.00000000e+00]
# the intercept value is -1.81188397619e-13
#    features  estimatedCoefficients
# 0      CRIM          -4.512835e-16
# 1        ZN           0.000000e+00
# 2     INDUS           4.440892e-16
# 3      CHAS          -3.302913e-15
# 4       NOX          -1.706968e-14
# 5        RM          -8.465451e-16
# 6       AGE          -1.110223e-16
# 7       DIS           1.734723e-16
# 8       RAD          -7.216450e-16
# 9       TAX           1.665335e-16
# ...

# %%
from sklearn.datasets import load_boston
from sklearn.linear_model import Ridge 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge 
from sklearn.linear_model import Lasso
import numpy as np

dataset = load_boston()
X=dataset.data
Y=dataset.target
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, random_state= 0)
#A) Ridge regression, using tuning parameter of 1
RidgeModel1=Ridge(alpha=1).fit(X_train, Y_train) 
#find the R2 metric with the .score 
print("Score of Ridge Regression with tuning parameter =1 is: ", RidgeModel1.score(X_test,Y_test))
print("number of coef. that are equal to zero with Ridge regression", np.sum(RidgeModel1.coef_==0))


#B) Ridge regression, using tuning parameter of 0
RidgeModel0=Ridge(alpha=0).fit(X_train, Y_train) 
#find the R2 metric with the .score 
print("Score of Ridge Regression with tuning parameter =0 is: ", RidgeModel0.score(X_test,Y_test))
print("number of coef. that are equal to zero with Ridge regression", np.sum(RidgeModel0.coef_==0))
# Out:
# Score of Ridge Regression with tuning parameter =1 is:  0.626511622377
# number of coef. that are equal to zero with Ridge regression 0
# Score of Ridge Regression with tuning parameter =0 is:  0.635362078667
# number of coef. that are equal to zero with Ridge regression 0

# %% [markdown]
#  We see that for larger values of alpha, the coefficient tends to go towards zero.When alpha = 1, the shrinkage penalty has some effect and tends to reduce the coefficients towards zero.
# 1)When we compare values for different tuning parameters alpha=0 and alpha =1 and linear regression .Large alpha=1 means less regularization strength that means it is close to the no regularization case
# 2)Small alpha value means more regularization and coefficients will be close to zero
# And the scores for each of those are 0.7790,0.626511 and 0.6353620 respectively and ridge regression with small aplha is better because it gets coefficients close to 0

# %% [markdown]
# <h4> Problem #4-3.Ridge Regression (part 2) </h4>  <br>
# Fit a ridge regression with λ = 5, 10, 50, 100, and 1000. For each value, report the estimated coefficients for the fitted model (do not just print summary, make a DataFrame with feature names and estimated coefficients)
# - What happens to the coefficients as you increase λ?
# - What happens to the flexibility of the model as you increase λ?

# %%
#Write your narrative answer here

#Using tuning parameter of 5
RidgeModel10=Ridge(alpha=5 ).fit(X_train, Y_train) # this uses alpha value of 0
#find the R2 metric with the .score
print("Score of Ridge Regression with tuning parameter =5 is", RidgeModel10.score(X_test,Y_test))
RidgeModel10=Ridge(alpha=10).fit(X_train, Y_train) # this uses alpha value of 0
#find the R2 metric with the .score
print("Score of Ridge Regression with tuning parameter =10 is", RidgeModel10.score(X_test,Y_test))
RidgeModel10=Ridge(alpha=50 ).fit(X_train, Y_train) # this uses alpha value of 0
#find the R2 metric with the .score
print("Score of Ridge Regression with tuning parameter =50 is", RidgeModel10.score(X_test,Y_test))
RidgeModel10=Ridge(alpha=100 ).fit(X_train, Y_train) # this uses alpha value of 0
#find the R2 metric with the .score
print("Score of Ridge Regression with tuning parameter =100 is", RidgeModel10.score(X_test,Y_test))
RidgeModel10=Ridge(alpha=1000 ).fit(X_train, Y_train) # this uses alpha value of 0
#find the R2 metric with the .score
print("Score of Ridge Regression with tuning parameter =1000 is", RidgeModel10.score(X_test,Y_test))
# Out:
# Score of Ridge Regression with tuning parameter =5 is 0.999999841517
# Score of Ridge Regression with tuning parameter =10 is 0.999999380014
# Score of Ridge Regression with tuning parameter =50 is 0.999986200448
# Score of Ridge Regression with tuning parameter =100 is 0.999949169601
# Score of Ridge Regression with tuning parameter =1000 is 0.996937458952

# %% [markdown]
# Large alpha value i.e 1000 means less regularization strength that means it is close to the no regularization case
# Small alpha value i.e 5 means more regularization and coefficients will be close to zero
# Flexibility of the model decreases with the increase in λ.And with very large λ, no features will be included

# %% [markdown]
# <h4> Problem #4-4 Lasso Regression </h4>  <br>
# In this part, you should download and analyze **"Boston House Prices"** dataset. <br>

# %% [markdown]
# Follow steps to answer questions.
# - Fit a linear regression model with all features and report the estimated coefficients for the fitted model (do not just print summary, make a DataFrame with feature names and estimated coefficients)
# -  Fit a lasso regression model with λ = 1. Report the estimated coefficients for the fitted model.
# -  Fit a lasso regression model with λ = 0. Report the estimated coefficients for the fitted model.
# - Compare estimated coefficients of lasso regression models with λ = 1 and λ = 0, ridge regression models with λ = 1 and λ = 0 and linear regression model. (you can use descriptive statistics)
#
# - What did you observe from this comparison?
#
# - Comment your observation.

# %%
#Write your narrative answer here
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
dataset = load_boston()
import pandas as pd
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
df = (pd.DataFrame(dataset.data, columns= dataset.feature_names))
df['target'] = dataset.target
Y = df['target']
X = df
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=0)
lm = linear_model.LinearRegression()
model = lm.fit(X_train,Y_train)
print ('the coefficient value is', lm.coef_)
print ('the intercept value is', lm.intercept_)
pd.DataFrame(list(zip(X.columns, lm.coef_)), columns = ['features','estimatedCoefficients'])
# Out:
# the coefficient value is [ -4.51283485e-16   0.00000000e+00   4.44089210e-16  -3.30291350e-15
#   -1.70696790e-14  -8.46545056e-16  -1.11022302e-16   1.73472348e-16
#   -7.21644966e-16   1.66533454e-16   4.75314232e-16   3.92047506e-16
#    8.32667268e-17   1.00000000e+00]
# the intercept value is -1.81188397619e-13
#    features  estimatedCoefficients
# 0      CRIM          -4.512835e-16
# 1        ZN           0.000000e+00
# 2     INDUS           4.440892e-16
# 3      CHAS          -3.302913e-15
# 4       NOX          -1.706968e-14
# 5        RM          -8.465451e-16
# 6       AGE          -1.110223e-16
# 7       DIS           1.734723e-16
# 8       RAD          -7.216450e-16
# 9       TAX           1.665335e-16
# 10  PTRATIO           4.753142e-16
# 11        B           3.920475e-16
# 12    LSTAT           8.326673e-17
# 13   target           1.000000e+00

# %%
#Write your narrative answer here
from sklearn.datasets import load_boston ;
from sklearn.model_selection import train_test_split ;
from sklearn.linear_model import LinearRegression;
import statsmodels.formula.api as smf;
from pandas import read_csv
dataset = load_boston() ;
X=dataset.data ; Y=dataset.target.reshape(-1,1)
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, random_state= 1)
# Linear regression
LinearRegModel=LinearRegression().fit(X_train,Y_train)
print("score of linear regression is,", LinearRegModel.score(X_test,Y_test))


#Lasso Regression with Alpha=1
lassoModel=Lasso( ).fit(X_train, Y_train)
LassoModel1=Lasso(alpha=1).fit(X_train, Y_train) 
print("Score of Lasso Regression with tuning parameter =1 is: ", LassoModel1.score(X_test,Y_test))
print("number of coef. that are equal to zero with Lasso regression when alpha =1 is: ", np.sum(LassoModel1.coef_==0))

#Lasso Regression with Alpha=0
lassoModel=Lasso( ).fit(X_train, Y_train)
LassoModel0=Lasso(alpha=0).fit(X_train, Y_train) 
print("Score of Lasso Regression with tuning parameter =0 is: ", LassoModel0.score(X_test,Y_test))
print("number of coef. that are equal to zero with Lasso regression when alpha =0 is: ", np.sum(LassoModel0.coef_==0))
# Out:
# score of linear regression is, 0.779025774914
# Score of Lasso Regression with tuning parameter =1 is:  0.66232599029
# number of coef. that are equal to zero with Lasso regression when alpha =1 is:  4
# Score of Lasso Regression with tuning parameter =0 is:  0.779025774914
# number of coef. that are equal to zero with Lasso regression when alpha =0 is:  0
# C:\Users\rvais\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# C:\Users\rvais\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# ...

# %% [markdown]
# When we compare the λ values for Lasso Regression and Linear regression.Lasso Regression with λ=0 gives the same value as that of Linear Regression.It gives the same result as linear regression estimator.

# %% [markdown]
# <h4> Problem #4-5.Lasso Regression (part 2) </h4>  <br>
# Fit a lasso regression with λ = 5, 10, 50, 100, and 1000. For each value, report the estimated coefficients for the fitted model (do not just print summary, make a DataFrmae with feature names and estimated coefficients)
# - What happens to the coefficients as you increase λ?
# - What happens to the flexibility of the model as you increase λ?

# %%
#Write your narrative answer here
from sklearn.datasets import load_boston
from sklearn.linear_model import Ridge 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge 
from sklearn.linear_model import Lasso
import numpy as np

dataset = load_boston()
X=dataset.data
Y=dataset.target
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, random_state= 0)

LassoModel001=Lasso(alpha=5).fit(X_train, Y_train) 
print("Score of Lasso Regression with tuning parameter =5 is: ", LassoModel001.score(X_test,Y_test))
print("number of coef. that are equal to zero with Lasso regression when alpha =5 is: ", np.sum(LassoModel001.coef_==0))

LassoModel001=Lasso(alpha=10).fit(X_train, Y_train) 
print("Score of Lasso Regression with tuning parameter =10 is: ", LassoModel001.score(X_test,Y_test))
print("number of coef. that are equal to zero with Lasso regression when alpha =10 is: ", np.sum(LassoModel001.coef_==0))

LassoModel001=Lasso(alpha=50).fit(X_train, Y_train) 
print("Score of Lasso Regression with tuning parameter =50 is: ", LassoModel001.score(X_test,Y_test))
print("number of coef. that are equal to zero with Lasso regression when alpha =50 is: ", np.sum(LassoModel001.coef_==0))


LassoModel001=Lasso(alpha=100).fit(X_train, Y_train) 
print("Score of Lasso Regression with tuning parameter =100 is: ", LassoModel001.score(X_test,Y_test))
print("number of coef. that are equal to zero with Lasso regression when alpha =100 is: ", np.sum(LassoModel001.coef_==0))


LassoModel001=Lasso(alpha=1000).fit(X_train, Y_train) 
print("Score of Lasso Regression with tuning parameter =1000 is: ", LassoModel001.score(X_test,Y_test))
print("number of coef. that are equal to zero with Lasso regression when alpha =1000 is: ", np.sum(LassoModel001.coef_==0))
# Out:
# Score of Lasso Regression with tuning parameter =5 is:  0.443863590518
# number of coef. that are equal to zero with Lasso regression when alpha =5 is:  8
# Score of Lasso Regression with tuning parameter =10 is:  0.399116107957
# number of coef. that are equal to zero with Lasso regression when alpha =10 is:  9
# Score of Lasso Regression with tuning parameter =50 is:  0.120514121814
# number of coef. that are equal to zero with Lasso regression when alpha =50 is:  10
# Score of Lasso Regression with tuning parameter =100 is:  0.118669161755
# number of coef. that are equal to zero with Lasso regression when alpha =100 is:  11
# Score of Lasso Regression with tuning parameter =1000 is:  -0.00111935920396
# number of coef. that are equal to zero with Lasso regression when alpha =1000 is:  13

# %% [markdown]
# As we increase λ the number of coefficients that are equal to zero increase.Flexibility decreases with increase in  λ because  fewer features included in the model.

# %% [markdown]
# <h3>  Problem #5.Logistic Regression [30 points] </h3>

# %% [markdown]
# <h4> Problem #5-1. </h4>  <br>
# We fit a logistic regression model to predict the probability that an individual will default on his/her credit card balance. We used the total balance (single feature) to fit the model and got the results shown in the table below.

# %% [markdown]
# |        |Coefficient| Std.error|Z -statistic|P-Value|
# |:--:|:-------------------------------:|
# |Intercept|-10.6513|0.3612|-29.5|<0.0001|
# |balance|0.0055|0.002|24.9|<0.0001|

# %% [markdown]
# - What is the parametric model used in logistic regression?
# - What is the probability that an individual with a balance equal to 15000 dollar will default?
# - What is the probability that an individual with balance equals to 800 dollar will not default?

# %% [markdown]
# 5.1.a
# Parametric model used in logistic regression is P(x)=![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# Probability that an individual will have balance of 15000 dollar and will be default is 1
# Probability that an individual will have balance of 800 dollar and will not  be default is 0.998

# %% [markdown]
# <h4> Problem #5-2. </h4>  <br>
#
# The coefficients of logistic regression are obtained by maximizing the likelihood function
#
# \begin{array} \\
# l(\beta) = \prod_{i:y_{i}=1} P(y_{i} = 1|x)\prod_{i{}':y_{{i}'}=0} (1-P(y_{{i}'} = 1|x))
# \end{array}
# Show that maximizing the
# likelihood function is equivalent to minimizing the cost function $J(\beta)$, such that.
# \begin{array} \\
# J(\beta) = -\sum [y_{i} log(P(y_{i} = 1|x)) + (1- y_{i})log(1- P(y_{i} = 1|x))]
# \end{array}
#
#
# Here $n$ is the number training examples. Mention one possible method for obtaining the
# optimal coefficients.

# %% [markdown]
# ![image.png](attachment:image.png)
